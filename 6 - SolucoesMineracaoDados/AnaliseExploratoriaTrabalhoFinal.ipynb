# %%
# Importando as bibliotecas necessarias
import pandas
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [16, 10]

# Fazendo o carregamento dos dados diretamente do UCI Machine Learning
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/letter-recognition/letter-recognition.data"

# Definindo o nome de cada coluna dos dados
nomes = ['lettr', 'x-box', 'y-box', 'width', 'high', 'onpix', 'x-bar', 'y-bar', 'x2bar', 'y2bar', 'xybar', 'x2ybr', 'xy2br', 'x-ege', 'xegvy', 'y-ege', 'yegvx']
dataset = pandas.read_csv(url, names=nomes)

print("Apresentando o shape dos dados (dimenssoes)")
print(dataset.shape)

print("Visualizando o conjunto inicial (head) dos dados, ou mais claramente, os 5 primeiros registros (head(5))")
print(dataset.head(5))

print("Conhecendo os dados estatisticos dos dados carregados (describe)")
print(dataset.describe())

print("Conhecendo a distribuicao dos dados por classes (class distribution)")
print(dataset.groupby('lettr').size())

print("Criando grafios de caixa da distribuicao das classes")
dataset.plot(kind='box', subplots=True, layout=(4,4), sharex=False, sharey=False)
plt.show()

print("Criando histogramas dos dados por classes")
dataset.hist()
plt.show()

print("Criando graficos de dispersao dos dados com paleta de cores")
##colors_palette = {'Iris-setosa': 'red', 'Iris-versicolor': 'yellow', 'Iris-virginica': 'green'}
##colors = [colors_palette[c] for c in dataset['lettr']]
scatter_matrix(dataset)
plt.show()
# Out:
# Apresentando o shape dos dados (dimenssoes)
# (20000, 17)
# Visualizando o conjunto inicial (head) dos dados, ou mais claramente, os 5 primeiros registros (head(5))
#   lettr  x-box  y-box  width  high  ...  xy2br  x-ege  xegvy  y-ege  yegvx
# 0     T      2      8      3     5  ...      8      0      8      0      8
# 1     I      5     12      3     7  ...      9      2      8      4     10
# 2     D      4     11      6     8  ...      7      3      7      3      9
# 3     N      7     11      6     6  ...     10      6     10      2      8
# 4     G      2      1      3     1  ...      9      1      7      5     10
#
# [5 rows x 17 columns]
# Conhecendo os dados estatisticos dos dados carregados (describe)
#               x-box         y-box  ...         y-ege        yegvx
# count  20000.000000  20000.000000  ...  20000.000000  20000.00000
# mean       4.023550      7.035500  ...      3.691750      7.80120
# std        1.913212      3.304555  ...      2.567073      1.61747
# min        0.000000      0.000000  ...      0.000000      0.00000
# 25%        3.000000      5.000000  ...      2.000000      7.00000
# 50%        4.000000      7.000000  ...      3.000000      8.00000
# 75%        5.000000      9.000000  ...      5.000000      9.00000
# max       15.000000     15.000000  ...     15.000000     15.00000
#
# [8 rows x 16 columns]
# Conhecendo a distribuicao dos dados por classes (class distribution)
# lettr
# A    789
# B    766
# C    736
# D    805
# E    768
# F    775
# G    773
# H    734
# I    755
# J    747
# K    739
# L    761
# M    792
# N    783
# O    753
# P    803
# Q    783
# R    758
# S    748
# T    796
# U    813
# V    764
# W    752
# X    787
# Y    786
# Z    734
# dtype: int64
# Criando grafios de caixa da distribuicao das classes
# Criando histogramas dos dados por classes
# Criando graficos de dispersao dos dados com paleta de cores
